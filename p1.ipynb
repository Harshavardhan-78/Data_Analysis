# %% [markdown]
# ##### Education,married,gender,selfemployed :nominal , they are names of things
# ##### application income,coapplicantIncome,loan id,loan amount:the values may be continous since they are numerical
# #####  loan amouunt term:discrete numerical

# %%
import pandas as pd
df=pd.read_csv('loan_approved.csv')
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
print(len(df['Loan_ID'].unique()))
#useless data
# Out:
# 614

# %% [markdown]
# ### Nominal

# %%
dfnominal = df[["Education", "Gender", "Married","Self_Employed"]]
print(dfnominal)
# Out:
#         Education  Gender Married Self_Employed
# 0        Graduate    Male      No            No
# 1        Graduate    Male     Yes            No
# 2        Graduate    Male     Yes           Yes
# 3    Not Graduate    Male     Yes            No
# 4        Graduate    Male      No            No
# ..            ...     ...     ...           ...
# 609      Graduate  Female      No            No
# 610      Graduate    Male     Yes            No
# 611      Graduate    Male     Yes            No
# 612      Graduate    Male     Yes            No
# 613      Graduate  Female      No           Yes
#
# [614 rows x 4 columns]

# %% [markdown]
# ### Continous

# %%
dfcunt= df[["LoanAmount", "ApplicantIncome" ,"CoapplicantIncome"]]
print(dfcunt)
# Out:
#      LoanAmount  ApplicantIncome  CoapplicantIncome
# 0           NaN             5849                0.0
# 1         128.0             4583             1508.0
# 2          66.0             3000                0.0
# 3         120.0             2583             2358.0
# 4         141.0             6000                0.0
# ..          ...              ...                ...
# 609        71.0             2900                0.0
# 610        40.0             4106                0.0
# 611       253.0             8072              240.0
# 612       187.0             7583                0.0
# 613       133.0             4583                0.0
#
# [614 rows x 3 columns]

# %%
print(df["CoapplicantIncome"].isna().sum())
# 0-no duplicates/
# Out:
# 0

# %% [markdown]
# ### discrete

# %%
dfdisc= df[["Loan_Amount_Term"]]
print(dfdisc)
# Out:
#      Loan_Amount_Term
# 0               360.0
# 1               360.0
# 2               360.0
# 3               360.0
# 4               360.0
# ..                ...
# 609             360.0
# 610             180.0
# 611             360.0
# 612             360.0
# 613             360.0
#
# [614 rows x 1 columns]

# %% [markdown]
# ### ordinal categorical

# %%
print(df["Dependents"].unique())
# Out:
# ['0' '1' '2' '3+' nan]

# %% [markdown]
# ### nominal categorical

# %%
print(df['Loan_Status (Approved)'].unique(
))
# Out:
# ['Y' 'N']

# %% [markdown]
# ### imputation

# %%
print(df.shape)
m=[]
for i in df:
    print(df[i].isna().sum())
    m.append(df[i])
# Out:
# (614, 13)
# 0
# 13
# 3
# 15
# 0
# 32
# 0
# 0
# 22
# 14
# 50
# 0
# 0

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
import matplotlib.pyplot as plt


plt.hist(df['LoanAmount'], bins=20, edgecolor='black')
plt.xlabel('Loan Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Loan Amount')
plt.show()

# %%
import seaborn as sns
sns.countplot(x='Gender', data=df)
plt.show()

# %%
# Out:
# ['Male' 'Female' nan]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import ydata_profiling as pp
#       3 # Generate the profile report
#       4 rep = pp.ProfileReport(df)
#
# ModuleNotFoundError: No module named 'ydata_profiling'
